# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from faker import Faker
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import random
from faker.providers import BaseProvider
from faker import Factory

# %%
myFactory = Faker()
myGenerator = Factory.create('es_ES')
fake = Faker()
myGenerator.random.seed(5467)
personas = random.randint(25, 50)

# %%
correos = {'emails': ['fulanito@ejemplo.com', 'menganito@ejemplo.com', 'zutanito@ejemplo.com']}
df = pd.DataFrame(correos, columns = ['emails'])
df['correos'] = df['emails'].astype(str)
df['emails'].str.partition('@').get(2)
# Out:
# 0    ejemplo.com
# 1    ejemplo.com
# 2    ejemplo.com
# Name: 2, dtype: object

# %%
globdf = pd.DataFrame(columns=('nombre'
        , 'email'))
def create_fake_stuff(myGenerator):
  
    for i in range(personas):
        stuff = [myGenerator.name(), 
                myGenerator.email()]
        globdf[i] = [myGenerator.email() for item in stuff]
        globdf[i] = globdf[i].astype(str)
        globdf2 = (globdf[i].str.partition('@').get(2))
        #print(globdf2)
        for n in range (0, 50):
            a = np.array(globdf2)
            a.tolist()
            print(a)
            plt.plot(a)
            plt.xlabel(n)
            plt.show
    
        #print(n)
                                           
            
      
if __name__ == '__main__':
    myGenerator = Factory.create('es_ES')
    create_fake_stuff(myGenerator)
# Out:
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ['hotmail.com' 'pombo.com']
# ...
