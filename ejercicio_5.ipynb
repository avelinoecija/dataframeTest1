# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from faker import Faker
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import random
from faker.providers import BaseProvider
from faker import Factory

# %%
df = pd.read_csv('carreras.csv')
print(df)
df.plot(kind='bar', x='Carreras', y='nAlumnos')
df.plot(kind='bar', x='Carreras', y='Desempleo(%)')
df.plot(kind='bar', x='Carreras', y='Notas')
# Out:
#        Carreras  Notas  nAlumnos  Desempleo(%)
# 0  Arquitectura      9       800            35
# 1       Derecho      6      1000            80
# 2    Enfermeria      8       400            20
# 3      Farmacia      5      1000            70
# 4  Fisioterapia      8       300            15
# 5          INEF      5       700            25
# 6   Informatica      8       500             5
# 7      Medicina      9       900            15
# 8    Psicologia      7       900            70
# 9        Teleco     10       200             3
